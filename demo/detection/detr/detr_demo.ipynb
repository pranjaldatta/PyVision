# %% [markdown]
# <a href="https://colab.research.google.com/github/pranjaldatta/PyVision/blob/master/demo/detection/detr/detr_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # End-to-End Object Detection with Transformers (DEtection TRansformer)
#
# DETR successfully uses Transformers in a conventional computer vision task such as detection. It reimagines the object detection pipeline and proposes an end-to-end pipeline. It views object detection as a direct set prediction problem.
#
# This is a stand alone notebook. Open it in colaboratory, use hardware acceleration if desired and just run the cells !
#
# While the notebook utilizes images that come with PyVision repo, feel free to use your own

# %%
# First we gotta clone the repo

# !git clone https://github.com/pranjaldatta/PyVision.git
# Out:
# Cloning into 'PyVision'...
# remote: Enumerating objects: 200, done.
# remote: Counting objects: 100% (200/200), done.
# remote: Compressing objects: 100% (162/162), done.
# remote: Total 620 (delta 66), reused 120 (delta 29), pack-reused 420
# Receiving objects: 100% (620/620), 11.56 MiB | 39.19 MiB/s, done.
# Resolving deltas: 100% (211/211), done.

# %%
# Lets confirm that we are using a GPU

# !nvidia-smi
# Out:
# Fri Jul 17 14:43:20 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Lets import the DETR Module

from PyVision.pyvision.detection import detr

import matplotlib.pyplot as plt

# %%
# We use images that come with the Repository to demo but feel free to use your 
# own images !

example_path = "PyVision/tests/detection/detr/"

# %%
# Lets check what models are available

print(detr.available_models())
# Out:
# ['detr-resnet50', 'detr-resnet101']

# %%
# Lets initialize the default detr-resnet50 model

model1 = detr.DETR(device="gpu")
# Out:
# fetching file ids for detr-resnet50
# Downloading...
# From: https://drive.google.com/uc?id=1yKx023hJV_CG6vqDRYSc2YV0FqiBGoXx
# To: /content/PyVision/pyvision/detection/detr/weights/detr-resnet50.pth
# 167MB [00:01, 96.7MB/s]
# weights downloaded.

# %%
time_taken, dets_img, dets = model1.detect(example_path+"zebra_test.jpg", save=False, show=False)

print("Time taken: {}\nDetections: {}".format(time_taken, dets))

# showing the original image for reference
plt.imshow(plt.imread(example_path+"zebra_test.jpg"))
plt.show()

# now showing the result image
plt.imshow(dets_img)
plt.show()
# Out:
# Time taken: 0.06494855880737305
# Detections: [{'scores': 0.9922112226486206, 'labels': 24, 'coords': [19.40460205078125, 86.52322387695312, 329.00018310546875, 480.8921203613281]}, {'scores': 0.9993477463722229, 'labels': 24, 'coords': [237.90663146972656, 69.26528930664062, 553.7160034179688, 492.45379638671875]}, {'scores': 0.9996486902236938, 'labels': 24, 'coords': [572.1699829101562, 118.57684326171875, 883.8941040039062, 499.104248046875]}]

# %%
# Lets Initialize  the detr-resnet101 model 
model2 = detr.DETR(model="detr-resnet101", device="gpu")
# Out:
# fetching file ids for detr-resnet101
# Downloading...
# From: https://drive.google.com/uc?id=1koBQ-cIbHGwpafzGNDJCRRpf89trTpuR
# To: /content/PyVision/pyvision/detection/detr/weights/detr-resnet101.pth
# 243MB [00:02, 98.3MB/s]
# weights downloaded.

# %%
time_taken, dets_img, dets = model1.detect(example_path+"cars_test.jpg", save=False, show=False)

print("Time taken: {}\nDetections: {}".format(time_taken, dets))

# showing the original image for reference
plt.imshow(plt.imread(example_path+"cars_test.jpg"))
plt.show()

# now showing the result image
plt.imshow(dets_img)
plt.show()
# Out:
# Time taken: 0.07572746276855469
# ...
